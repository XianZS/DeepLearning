# %%
import sympy

# %%
J, w = sympy.symbols("J,w")

J = w**3 + 3 * w

# %%
J
# Out:
# w**3 + 3*w

# %%
res=sympy.diff(J,w)

# %%
res
# Out:
# 3*w**2 + 3

# %%
new_res=sympy.diff(res,w)

# %%
new_res
# Out:
# 6*w
